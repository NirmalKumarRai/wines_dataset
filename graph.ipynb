# %%
import pandas as pd
# import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
style.use("fivethirtyeight")
df = pd.DataFrame({'day': [1, 2, 3, 4, 5], 'visitors': [200, 302, 200, 590, 680], 'Bounce_rate': [20, 30, 40, 50, 60]})
df.set_index('day', inplace=True)

df.plot()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
style.use("fivethirtyeight")
df = pd.DataFrame({'day':[1.75,2.25,3,3.75,4.25],'visitors':[100,400,200,400,100],'Bounce_rate':[100,200,150,200,100]})
df.set_index('day',inplace=True)
df = df.rename(columns={'visitors':'user'})

df.plot()
plt.show()
