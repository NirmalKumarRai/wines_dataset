# %%
import pandas as pd
review = pd.read_csv("D:/data science/winemag-data_first150k.csv.zip", index_col=1)
pd.set_option('display.max_row',10)

# %%
# review.drop('description',inplace =True , axis=1)

# %%
review
# Out:
#           Unnamed: 0                                        description  \
# country
# Italy              0  Aromas include tropical fruit, broom, brimston...
# Portugal           1  This is ripe and fruity, a wine that is smooth...
# US                 2  Tart and snappy, the flavors of lime flesh and...
# US                 3  Pineapple rind, lemon pith and orange blossom ...
# US                 4  Much like the regular bottling from 2012, this...
# ...              ...                                                ...
# Germany       129966  Notes of honeysuckle and cantaloupe sweeten th...
# US            129967  Citation is given as much as a decade of bottl...
# France        129968  Well-drained gravel soil gives this wine its c...
# France        129969  A dry style of Pinot Gris, this is crisp with ...
# France        129970  Big, rich and off-dry, this is powered by inte...
#
#                                      designation  points  price  \
# country
# ...

# %%
review.groupby('points').points.count()
# Out:
# points
# 80      397
# 81      692
# 82     1836
# 83     3025
# 84     6480
#        ...
# 96      523
# 97      229
# 98       77
# 99       33
# 100      19
# Name: points, Length: 21, dtype: int64

# %%
review.groupby('price').price.count()
# Out:
# price
# 4.0        11
# 5.0        46
# 6.0       120
# 7.0       433
# 8.0       892
#          ...
# 1900.0      1
# 2000.0      2
# 2013.0      1
# 2500.0      2
# 3300.0      1
# Name: price, Length: 390, dtype: int64

# %%
review.groupby('points').price.min()
# Out:
# points
# 80      5.0
# 81      5.0
# 82      4.0
# 83      4.0
# 84      4.0
#        ...
# 96     20.0
# 97     35.0
# 98     50.0
# 99     44.0
# 100    80.0
# Name: price, Length: 21, dtype: float64

# %%
xy1 = review.groupby('winery').apply(lambda df: df.title.iloc[0])

# %%
xy1
# Out:
# winery
# 1+1=3                                     1+1=3 NV Rosé Sparkling (Cava)
# 10 Knots                            10 Knots 2010 Viognier (Paso Robles)
# 100 Percent Wine              100 Percent Wine 2015 Moscato (California)
# 1000 Stories           1000 Stories 2013 Bourbon Barrel Aged Zinfande...
# 1070 Green                  1070 Green 2011 Sauvignon Blanc (Rutherford)
#                                              ...
# Órale                       Órale 2011 Cabronita Red (Santa Ynez Valley)
# Öko                    Öko 2013 Made With Organically Grown Grapes Ma...
# Ökonomierat Rebholz    Ökonomierat Rebholz 2007 Von Rotliegenden Spät...
# àMaurice               àMaurice 2013 Fred Estate Syrah (Walla Walla V...
# Štoka                                    Štoka 2009 Izbrani Teran (Kras)
# Length: 16757, dtype: object

# %%
review.groupby(['country',"province"]).apply(lambda df : df.loc[df.points.idxmax()])
# Out:
#                                       Unnamed: 0  \
# country   province
# Argentina Mendoza Province Argentina        17.0
#                            Argentina       224.0
#                            Argentina       231.0
#                            Argentina       253.0
#                            Argentina       261.0
# ...                                          ...
# Uruguay   Uruguay          Uruguay      113525.0
#                            Uruguay      116717.0
#                            Uruguay      128749.0
#                            Uruguay      129436.0
#                            Uruguay      129437.0
#
#                                                                             description  \
# country   province
# Argentina Mendoza Province Argentina  Raw black-cherry aromas are direct and simple ...
#                            Argentina  Blackberry and road-tar aromas are dark and st...
# ...

# %%
review.groupby('country').points.agg([len,min,max])
# Out:
#                           len  min  max
# country
# Argentina                3800   80   97
# Armenia                     2   87   88
# Australia                2329   80  100
# Austria                  3345   82   98
# Bosnia and Herzegovina      2   85   88
# ...                       ...  ...  ...
# Switzerland                 7   83   90
# Turkey                     90   84   92
# US                      54504   80  100
# Ukraine                    14   82   88
# Uruguay                   109   80   92
#
# [43 rows x 3 columns]

# %%
countries_reviewed = review.groupby(['country', 'province']).description.agg([len])
countries_reviewed
# Out:
#                              len
# country   province
# Argentina Mendoza Province  3264
#           Other              536
# Armenia   Armenia              2
# Australia Australia Other    245
#           New South Wales     85
# ...                          ...
# Uruguay   Juanico             12
#           Montevideo          11
#           Progreso            11
#           San Jose             3
#           Uruguay             24
#
# [425 rows x 1 columns]

# %%
mi = countries_reviewed.index
type(mi)
# Out:
# pandas.core.indexes.multi.MultiIndex

# %%
mi
# Out:
# MultiIndex([('Argentina',  'Mendoza Province'),
#             ('Argentina',             'Other'),
#             (  'Armenia',           'Armenia'),
#             ('Australia',   'Australia Other'),
#             ('Australia',   'New South Wales'),
#             ('Australia',   'South Australia'),
#             ('Australia',          'Tasmania'),
#             ('Australia',          'Victoria'),
#             ('Australia', 'Western Australia'),
#             (  'Austria',           'Austria'),
#             ...
#             (       'US',        'Washington'),
#             (       'US', 'Washington-Oregon'),
#             (  'Ukraine',           'Ukraine'),
#             (  'Uruguay',         'Atlantida'),
#             (  'Uruguay',         'Canelones'),
#             (  'Uruguay',           'Juanico'),
#             (  'Uruguay',        'Montevideo'),
#             (  'Uruguay',          'Progreso'),
#             (  'Uruguay',          'San Jose'),
# ...

# %%
countries_reviewed.reset_index()
# Out:
#        country          province   len
# 0    Argentina  Mendoza Province  3264
# 1    Argentina             Other   536
# 2      Armenia           Armenia     2
# 3    Australia   Australia Other   245
# 4    Australia   New South Wales    85
# ..         ...               ...   ...
# 420    Uruguay           Juanico    12
# 421    Uruguay        Montevideo    11
# 422    Uruguay          Progreso    11
# 423    Uruguay          San Jose     3
# 424    Uruguay           Uruguay    24
#
# [425 rows x 3 columns]

# %%
countries_reviewed=countries_reviewed.reset_index()
countries_reviewed=countries_reviewed.sort_values(by='len')

# %%
countries_reviewed
# Out:
#           country               province    len
# 179        Greece  Muscat of Kefallonian      1
# 192        Greece          Sterea Ellada      1
# 194        Greece                 Thraki      1
# 354  South Africa             Paardeberg      1
# 40         Brazil       Serra do Sudeste      1
# ..            ...                    ...    ...
# 409            US                 Oregon   5373
# 227         Italy                Tuscany   5897
# 118        France               Bordeaux   5941
# 415            US             Washington   8639
# 392            US             California  36247
#
# [425 rows x 3 columns]

# %%
countries_reviewed.sort_values(by=['country', 'len'])
# Out:
#        country          province   len
# 1    Argentina             Other   536
# 0    Argentina  Mendoza Province  3264
# 2      Armenia           Armenia     2
# 6    Australia          Tasmania    42
# 4    Australia   New South Wales    85
# ..         ...               ...   ...
# 421    Uruguay        Montevideo    11
# 422    Uruguay          Progreso    11
# 420    Uruguay           Juanico    12
# 424    Uruguay           Uruguay    24
# 419    Uruguay         Canelones    43
#
# [425 rows x 3 columns]

# %%
reviews_written = review.groupby('taster_twitter_handle').size()
reviews = review

# %%
reviews_written
# Out:
# taster_twitter_handle
# @AnneInVino          3685
# @JoeCz               5147
# @bkfiona               27
# @gordone_cellars     4177
# @kerinokeefe        10776
#                     ...
# @vossroger          25514
# @wawinereport        4966
# @wineschach         15134
# @winewchristina         6
# @worldwineguys       1005
# Length: 15, dtype: int64

# %%
reviews_written = reviews.groupby('taster_twitter_handle').taster_twitter_handle.count()

# %%
reviews_written
# Out:
# taster_twitter_handle
# @AnneInVino          3685
# @JoeCz               5147
# @bkfiona               27
# @gordone_cellars     4177
# @kerinokeefe        10776
#                     ...
# @vossroger          25514
# @wawinereport        4966
# @wineschach         15134
# @winewchristina         6
# @worldwineguys       1005
# Name: taster_twitter_handle, Length: 15, dtype: int64

# %%
best_rating_per_price = reviews.groupby('price').points.max()
best_rating_per_price.sort_index()
# Out:
# price
# 4.0       86
# 5.0       87
# 6.0       88
# 7.0       91
# 8.0       91
#           ..
# 1900.0    98
# 2000.0    97
# 2013.0    91
# 2500.0    96
# 3300.0    88
# Name: points, Length: 390, dtype: int64

# %%
price_extremes = reviews.groupby('variety')['price'].agg([min,max])
price_extremes
# Out:
#               min    max
# variety
# Abouriou     15.0   75.0
# Agiorgitiko  10.0   66.0
# Aglianico     6.0  180.0
# Aidani       27.0   27.0
# Airen         8.0   10.0
# ...           ...    ...
# Zinfandel     5.0  100.0
# Zlahtina     13.0   16.0
# Zweigelt      9.0   70.0
# Çalkarası    19.0   19.0
# Žilavka      15.0   15.0
#
# [707 rows x 2 columns]

# %%
review.describe()
# Out:
#           Unnamed: 0         points          price
# count  129971.000000  129971.000000  120975.000000
# mean    64985.000000      88.447138      35.363389
# std     37519.540256       3.039730      41.022218
# min         0.000000      80.000000       4.000000
# 25%     32492.500000      86.000000      17.000000
# 50%     64985.000000      88.000000      25.000000
# 75%     97477.500000      91.000000      42.000000
# max    129970.000000     100.000000    3300.000000

# %%
reviewer_mean_ratings = reviews.groupby('taster_name')['points'].mean()
reviewer_mean_ratings
# Out:
# taster_name
# Alexander Peartree    85.855422
# Anna Lee C. Iijima    88.415629
# Anne Krebiehl MW      90.562551
# Carrie Dykes          86.395683
# Christina Pickard     87.833333
#                         ...
# Paul Gregutt          89.082564
# Roger Voss            88.708003
# Sean P. Sullivan      88.755739
# Susan Kostrzewa       86.609217
# Virginie Boone        89.213379
# Name: points, Length: 19, dtype: float64

# %%
country_variety_counts = reviews.groupby(['country','variety']).size().sort_values(ascending=False)
country_variety_counts
# Out:
# country  variety
# US       Pinot Noir                  9885
#          Cabernet Sauvignon          7315
#          Chardonnay                  6801
# France   Bordeaux-style Red Blend    4725
# Italy    Red Blend                   3624
#                                      ...
# Mexico   Cinsault                       1
#          Grenache                       1
#          Merlot                         1
#          Rosado                         1
# Uruguay  White Blend                    1
# Length: 1612, dtype: int64

# %%
review.points.value_counts()
# Out:
# 88     17207
# 87     16933
# 90     15410
# 86     12600
# 89     12226
#        ...
# 80       397
# 97       229
# 98        77
# 99        33
# 100       19
# Name: points, Length: 21, dtype: int64

# %%
review.groupby('points').size()
# Out:
# points
# 80      397
# 81      692
# 82     1836
# 83     3025
# 84     6480
#        ...
# 96      523
# 97      229
# 98       77
# 99       33
# 100      19
# Length: 21, dtype: int64

# %%
review.groupby('points')['price'].max()
# Out:
# points
# 80       69.0
# 81      130.0
# 82      150.0
# 83      225.0
# 84      225.0
#         ...
# 96     2500.0
# 97     2000.0
# 98     1900.0
# 99      850.0
# 100    1500.0
# Name: price, Length: 21, dtype: float64

# %%
reviews.groupby('winery').apply(lambda df: df.title.iloc[0])
# Out:
# winery
# 1+1=3                                     1+1=3 NV Rosé Sparkling (Cava)
# 10 Knots                            10 Knots 2010 Viognier (Paso Robles)
# 100 Percent Wine              100 Percent Wine 2015 Moscato (California)
# 1000 Stories           1000 Stories 2013 Bourbon Barrel Aged Zinfande...
# 1070 Green                  1070 Green 2011 Sauvignon Blanc (Rutherford)
#                                              ...
# Órale                       Órale 2011 Cabronita Red (Santa Ynez Valley)
# Öko                    Öko 2013 Made With Organically Grown Grapes Ma...
# Ökonomierat Rebholz    Ökonomierat Rebholz 2007 Von Rotliegenden Spät...
# àMaurice               àMaurice 2013 Fred Estate Syrah (Walla Walla V...
# Štoka                                    Štoka 2009 Izbrani Teran (Kras)
# Length: 16757, dtype: object

# %%
review.dtypes
# Out:
# Unnamed: 0                 int64
# description               object
# designation               object
# points                     int64
# price                    float64
#                           ...
# taster_name               object
# taster_twitter_handle     object
# title                     object
# variety                   object
# winery                    object
# Length: 13, dtype: object

# %%
review.price.dtype
# Out:
# dtype('float64')

# %%
review[pd.isnull(review.taster_name)]
# Out:
#          Unnamed: 0                                        description  \
# country
# Italy            31  Merlot and Nero d'Avola form the base for this...
# Italy            32  Part of the extended Calanìca series, this Gri...
# US               33  Rustic and dry, this has flavors of berries, c...
# US               34  This shows a tart, green gooseberry flavor tha...
# Italy            37  This concentrated Cabernet offers aromas of cu...
# ...             ...                                                ...
# Italy        129852  Here's an easy blend of Cabernet Sauvignon and...
# US           129914  Fritz has made tremendous progress with Cab ov...
# US           129920  Shows the clean, citrus acid juiciness and sil...
# Italy        129929  This luminous sparkler has a sweet, fruit-forw...
# US           129940  This is the winery's bells and whistles Chardo...
#
#                           designation  points  price           province  \
# country
# ...

# %%
countries_reviewed=countries_reviewed.reset_index()

# %%
countries_reviewed=review

# %%
review
# Out:
#           Unnamed: 0                                        description  \
# country
# Italy              0  Aromas include tropical fruit, broom, brimston...
# Portugal           1  This is ripe and fruity, a wine that is smooth...
# US                 2  Tart and snappy, the flavors of lime flesh and...
# US                 3  Pineapple rind, lemon pith and orange blossom ...
# US                 4  Much like the regular bottling from 2012, this...
# ...              ...                                                ...
# Germany       129966  Notes of honeysuckle and cantaloupe sweeten th...
# US            129967  Citation is given as much as a decade of bottl...
# France        129968  Well-drained gravel soil gives this wine its c...
# France        129969  A dry style of Pinot Gris, this is crisp with ...
# France        129970  Big, rich and off-dry, this is powered by inte...
#
#                                      designation  points  price  \
# country
# ...

# %%
review[pd.notnull(review.price)]
# Out:
#           Unnamed: 0                                        description  \
# country
# Portugal           1  This is ripe and fruity, a wine that is smooth...
# US                 2  Tart and snappy, the flavors of lime flesh and...
# US                 3  Pineapple rind, lemon pith and orange blossom ...
# US                 4  Much like the regular bottling from 2012, this...
# Spain              5  Blackberry and raspberry aromas show a typical...
# ...              ...                                                ...
# Germany       129966  Notes of honeysuckle and cantaloupe sweeten th...
# US            129967  Citation is given as much as a decade of bottl...
# France        129968  Well-drained gravel soil gives this wine its c...
# France        129969  A dry style of Pinot Gris, this is crisp with ...
# France        129970  Big, rich and off-dry, this is powered by inte...
#
#                                      designation  points  price  \
# country
# ...

# %%
review.price.fillna('nkr')
# Out:
# country
# Italy        nkr
# Portugal    15.0
# US          14.0
# US          13.0
# US          65.0
#             ...
# Germany     28.0
# US          75.0
# France      30.0
# France      32.0
# France      21.0
# Name: price, Length: 129971, dtype: object

# %%
reviews.reset_index()
# Out:
#          country  Unnamed: 0  \
# 0          Italy           0
# 1       Portugal           1
# 2             US           2
# 3             US           3
# 4             US           4
# ...          ...         ...
# 129966   Germany      129966
# 129967        US      129967
# 129968    France      129968
# 129969    France      129969
# 129970    France      129970
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...

# %%
reviews.region_1.fillna('hey')
# Out:
# country
# Italy                      Etna
# Portugal                    hey
# US            Willamette Valley
# US          Lake Michigan Shore
# US            Willamette Valley
#                    ...
# Germany                     hey
# US                       Oregon
# France                   Alsace
# France                   Alsace
# France                   Alsace
# Name: region_1, Length: 129971, dtype: object

# %%
reviews.taster_twitter_handle.replace("@kerinokeefe", "@kerino")
# Out:
# country
# Italy           @kerino
# Portugal     @vossroger
# US          @paulgwine
# US                  NaN
# US          @paulgwine
#                ...
# Germany             NaN
# US          @paulgwine
# France       @vossroger
# France       @vossroger
# France       @vossroger
# Name: taster_twitter_handle, Length: 129971, dtype: object

# %%
reviews.taster_twitter_handle.fillna('habibi')
# Out:
# country
# Italy       @kerinokeefe
# Portugal      @vossroger
# US           @paulgwine
# US                habibi
# US           @paulgwine
#                 ...
# Germany           habibi
# US           @paulgwine
# France        @vossroger
# France        @vossroger
# France        @vossroger
# Name: taster_twitter_handle, Length: 129971, dtype: object

# %%
reviews[reviews.price.isnull()]
# Out:
#           Unnamed: 0                                        description  \
# country
# Italy              0  Aromas include tropical fruit, broom, brimston...
# Italy             13  This is dominated by oak and oak-driven aromas...
# France            30  Red cherry fruit comes laced with light tannin...
# Italy             31  Merlot and Nero d'Avola form the base for this...
# Italy             32  Part of the extended Calanìca series, this Gri...
# ...              ...                                                ...
# Italy         129844  Doga delle Clavule is a neutral, mineral-drive...
# Portugal      129860  This rich wine has a firm structure as well as...
# Portugal      129863  This mature wine that has 50% Touriga Nacional...
# Italy         129893  Aromas of passion fruit, hay and a vegetal not...
# France        129964  Initially quite muted, this wine slowly develo...
#
#                            designation  points  price           province  \
# country
# ...

# %%
reviews[pd.isnull(review.price)]
# Out:
#           Unnamed: 0                                        description  \
# country
# Italy              0  Aromas include tropical fruit, broom, brimston...
# Italy             13  This is dominated by oak and oak-driven aromas...
# France            30  Red cherry fruit comes laced with light tannin...
# Italy             31  Merlot and Nero d'Avola form the base for this...
# Italy             32  Part of the extended Calanìca series, this Gri...
# ...              ...                                                ...
# Italy         129844  Doga delle Clavule is a neutral, mineral-drive...
# Portugal      129860  This rich wine has a firm structure as well as...
# Portugal      129863  This mature wine that has 50% Touriga Nacional...
# Italy         129893  Aromas of passion fruit, hay and a vegetal not...
# France        129964  Initially quite muted, this wine slowly develo...
#
#                            designation  points  price           province  \
# country
# ...

# %%
reviews.price.isnull()
# Out:
# country
# Italy        True
# Portugal    False
# US          False
# US          False
# US          False
#             ...
# Germany     False
# US          False
# France      False
# France      False
# France      False
# Name: price, Length: 129971, dtype: bool

# %%
reviews.region_2.fillna("Unknown")
# Out:
# country
# Italy                 Unknown
# Portugal              Unknown
# US          Willamette Valley
# US                    Unknown
# US          Willamette Valley
#                   ...
# Germany               Unknown
# US               Oregon Other
# France                Unknown
# France                Unknown
# France                Unknown
# Name: region_2, Length: 129971, dtype: object

# %%
review.rename(columns={'points':'score'})
# Out:
#           Unnamed: 0                                        description  \
# country
# Italy              0  Aromas include tropical fruit, broom, brimston...
# Portugal           1  This is ripe and fruity, a wine that is smooth...
# US                 2  Tart and snappy, the flavors of lime flesh and...
# US                 3  Pineapple rind, lemon pith and orange blossom ...
# US                 4  Much like the regular bottling from 2012, this...
# ...              ...                                                ...
# Germany       129966  Notes of honeysuckle and cantaloupe sweeten th...
# US            129967  Citation is given as much as a decade of bottl...
# France        129968  Well-drained gravel soil gives this wine its c...
# France        129969  A dry style of Pinot Gris, this is crisp with ...
# France        129970  Big, rich and off-dry, this is powered by inte...
#
#                                      designation  score  price  \
# country
# ...

# %%
reviews.rename_axis("wines", axis='rows').rename_axis("fields", axis='columns')
# Out:
# fields    Unnamed: 0                                        description  \
# wines
# Italy              0  Aromas include tropical fruit, broom, brimston...
# Portugal           1  This is ripe and fruity, a wine that is smooth...
# US                 2  Tart and snappy, the flavors of lime flesh and...
# US                 3  Pineapple rind, lemon pith and orange blossom ...
# US                 4  Much like the regular bottling from 2012, this...
# ...              ...                                                ...
# Germany       129966  Notes of honeysuckle and cantaloupe sweeten th...
# US            129967  Citation is given as much as a decade of bottl...
# France        129968  Well-drained gravel soil gives this wine its c...
# France        129969  A dry style of Pinot Gris, this is crisp with ...
# France        129970  Big, rich and off-dry, this is powered by inte...
#
# fields                               designation  points  price  \
# wines
# ...
